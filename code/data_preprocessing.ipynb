# %%
import pandas as pd
sql_records_df = pd.read_csv("sql_df.csv")

# %%
sql_records_df
# Out:
#                                                 full_url    event_time  \
# 0                           /details.php?prod=5&type=%3F  1.681395e+09
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...  1.681395e+09
# 2                           /details.php?prod=5&type=%3F  1.681395e+09
# 3                        /details.php?prod=7831&type=%3F  1.681395e+09
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...  1.681395e+09
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  1.681396e+09
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  1.681396e+09
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  1.681396e+09
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  1.681396e+09
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  1.681396e+09
#
#            hostname  injection
# 0      192.168.43.6          1
# 1      192.168.43.6          1
# 2      192.168.43.6          1
# 3      192.168.43.6          1
# 4      192.168.43.6          1
# ...             ...        ...
# 21398  192.168.43.6          0
# 21399  192.168.43.6          0
# 21400  192.168.43.6          0
# 21401  192.168.43.6          0
# 21402  192.168.43.6          0
#
# [21403 rows x 4 columns]

# %%
from urllib.parse import unquote, urlparse, parse_qs

def url_decoder(full_url):
    full_url = unquote(full_url)
    return full_url

sql_records_df['parsed_url'] = sql_records_df['full_url'].apply(url_decoder)

# %%
sql_records_df
# Out:
#                                                 full_url    event_time  \
# 0                           /details.php?prod=5&type=%3F  1.681395e+09
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...  1.681395e+09
# 2                           /details.php?prod=5&type=%3F  1.681395e+09
# 3                        /details.php?prod=7831&type=%3F  1.681395e+09
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...  1.681395e+09
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  1.681396e+09
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  1.681396e+09
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  1.681396e+09
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  1.681396e+09
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  1.681396e+09
#
#            hostname  injection  \
# 0      192.168.43.6          1
# 1      192.168.43.6          1
# 2      192.168.43.6          1
# 3      192.168.43.6          1
# 4      192.168.43.6          1
# ...             ...        ...
# 21398  192.168.43.6          0
# 21399  192.168.43.6          0
# 21400  192.168.43.6          0
# 21401  192.168.43.6          0
# 21402  192.168.43.6          0
#
#                                               parsed_url
# 0                             /details.php?prod=5&type=?
# 1      /details.php?prod=5&type=?&GIuz=7549 AND 1=1 U...
# 2                             /details.php?prod=5&type=?
# 3                          /details.php?prod=7831&type=?
# 4                   /details.php?prod=5"',.(((,,,&type=?
# ...                                                  ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...
#
# [21403 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup

# scraping keywordow
sql_keywords = []

url = "https://www.w3schools.com/sql/sql_ref_keywords.asp"
resp = requests.get(url)
print(resp.status_code)

soup = BeautifulSoup(resp.text, 'html.parser')
for keyword in soup.findAll('td'):
    keyword = keyword.find('a')
    if(keyword!=None):
        sql_keywords.append(keyword.text)
# Out:
# 200

# %%
import re

sql_keywords_counter = []

for record in sql_records_df["parsed_url"]:
    tmp = 0
    for keyword in sql_keywords:
        if(re.search(keyword,record)):
            tmp = tmp +1
    sql_keywords_counter.append(tmp)

sql_records_df["sql_keyword"] = sql_keywords_counter

# %%
sql_records_df
# Out:
#                                                 full_url    event_time  \
# 0                           /details.php?prod=5&type=%3F  1.681395e+09
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...  1.681395e+09
# 2                           /details.php?prod=5&type=%3F  1.681395e+09
# 3                        /details.php?prod=7831&type=%3F  1.681395e+09
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...  1.681395e+09
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  1.681396e+09
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  1.681396e+09
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  1.681396e+09
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  1.681396e+09
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  1.681396e+09
#
#            hostname  injection  \
# 0      192.168.43.6          1
# 1      192.168.43.6          1
# 2      192.168.43.6          1
# 3      192.168.43.6          1
# 4      192.168.43.6          1
# ...             ...        ...
# 21398  192.168.43.6          0
# 21399  192.168.43.6          0
# 21400  192.168.43.6          0
# 21401  192.168.43.6          0
# 21402  192.168.43.6          0
#
#                                               parsed_url  sql_keyword
# 0                             /details.php?prod=5&type=?            0
# 1      /details.php?prod=5&type=?&GIuz=7549 AND 1=1 U...            8
# 2                             /details.php?prod=5&type=?            0
# 3                          /details.php?prod=7831&type=?            0
# 4                   /details.php?prod=5"',.(((,,,&type=?            0
# ...                                                  ...          ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...            1
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...            0
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...            0
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...            0
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...            0
#
# [21403 rows x 6 columns]

# %%
params_length = []

for record in sql_records_df["parsed_url"]:
    tmp = 0
    params = []

    for i in parse_qs(record).values():
       # print(str(i))
       # print(re.search(r"\['(\b.*)'\]",str(i)).group(1))
       # params.append(re.search(r"\['(\b.*)'\]",str(i)).group(1))
        params.append(str(i)[2:-2])
    
    for param in params:
        tmp = tmp + len((param))

    params_length.append(tmp)
  
sql_records_df["params_length"] = params_length

# %%
sql_records_df
# Out:
#                                                 full_url    event_time  \
# 0                           /details.php?prod=5&type=%3F  1.681395e+09
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...  1.681395e+09
# 2                           /details.php?prod=5&type=%3F  1.681395e+09
# 3                        /details.php?prod=7831&type=%3F  1.681395e+09
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...  1.681395e+09
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  1.681396e+09
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  1.681396e+09
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  1.681396e+09
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  1.681396e+09
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  1.681396e+09
#
#            hostname  injection  \
# 0      192.168.43.6          1
# 1      192.168.43.6          1
# 2      192.168.43.6          1
# 3      192.168.43.6          1
# 4      192.168.43.6          1
# ...             ...        ...
# 21398  192.168.43.6          0
# 21399  192.168.43.6          0
# 21400  192.168.43.6          0
# 21401  192.168.43.6          0
# 21402  192.168.43.6          0
#
#                                               parsed_url  sql_keyword  \
# 0                             /details.php?prod=5&type=?            0
# 1      /details.php?prod=5&type=?&GIuz=7549 AND 1=1 U...            8
# 2                             /details.php?prod=5&type=?            0
# 3                          /details.php?prod=7831&type=?            0
# 4                   /details.php?prod=5"',.(((,,,&type=?            0
# ...                                                  ...          ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...            1
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...            0
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...            0
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...            0
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...            0
#
#        params_length
# 0                  2
# 1                178
# 2                  2
# 3                  5
# 4                 13
# ...              ...
# 21398             48
# 21399             34
# 21400             37
# 21401             32
# 21402             28
#
# [21403 rows x 7 columns]

# %%
indexes = []
base_event_time = 0
period = 10 # value in seconds


sql_records_df["request_volume"] = "NaN"
hostname_list = sql_records_df.hostname.unique()

for hostname in hostname_list:
    base_event_time = sql_records_df.loc[sql_records_df["hostname"] == hostname]["event_time"].to_list()[0]

    for time in sql_records_df.loc[sql_records_df["hostname"] == hostname]["event_time"].to_list():
        if(time < (float(base_event_time) + float(period))):
            indexes.append(sql_records_df.loc[(sql_records_df["hostname"] == hostname) & (sql_records_df["event_time"] == time)].index[0])  
                   
        else:
            #print(indexes)
            for index in indexes:
                sql_records_df.at[index , "request_volume"] = len(indexes)/period 
            
            indexes = []
            indexes.append(sql_records_df.loc[(sql_records_df["hostname"] == hostname) & (sql_records_df["event_time"] == time)].index[0])  
            base_event_time =  time
            #print(f'{base_event_time} --  {indexes}')
            
    for index in indexes:
        sql_records_df.at[index , "request_volume"] = len(indexes)/period
    indexes = []

# %%
sql_records_df
# Out:
#                                                 full_url    event_time  \
# 0                           /details.php?prod=5&type=%3F  1.681395e+09
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...  1.681395e+09
# 2                           /details.php?prod=5&type=%3F  1.681395e+09
# 3                        /details.php?prod=7831&type=%3F  1.681395e+09
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...  1.681395e+09
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  1.681396e+09
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  1.681396e+09
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  1.681396e+09
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  1.681396e+09
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  1.681396e+09
#
#            hostname  injection  \
# 0      192.168.43.6          1
# 1      192.168.43.6          1
# 2      192.168.43.6          1
# 3      192.168.43.6          1
# 4      192.168.43.6          1
# ...             ...        ...
# 21398  192.168.43.6          0
# 21399  192.168.43.6          0
# 21400  192.168.43.6          0
# 21401  192.168.43.6          0
# 21402  192.168.43.6          0
#
#                                               parsed_url  sql_keyword  \
# 0                             /details.php?prod=5&type=?            0
# 1      /details.php?prod=5&type=?&GIuz=7549 AND 1=1 U...            8
# 2                             /details.php?prod=5&type=?            0
# 3                          /details.php?prod=7831&type=?            0
# 4                   /details.php?prod=5"',.(((,,,&type=?            0
# ...                                                  ...          ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...            1
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...            0
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...            0
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...            0
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...            0
#
#        params_length request_volume
# 0                  2            4.2
# 1                178            4.2
# 2                  2            4.2
# 3                  5            4.2
# 4                 13            4.2
# ...              ...            ...
# 21398             48            0.5
# 21399             34            0.5
# 21400             37            0.5
# 21401             32            0.5
# 21402             28            0.5
#
# [21403 rows x 8 columns]

# %%
# * need to be escaped in regexp engine to be interpreted as character
special_chars_list = ['--', '\'' , '\"', ':', ';', '#', '/\*', '\*/']

special_chars_count = []

for record in sql_records_df["parsed_url"]:
    counter_tmp = 0
    for element in special_chars_list:
        if(re.search(element, record)):
            counter_tmp = counter_tmp + 1
    special_chars_count.append(counter_tmp)

sql_records_df["special_chars"] = special_chars_count

# %%
sql_records_df
# Out:
#                                                 full_url    event_time  \
# 0                           /details.php?prod=5&type=%3F  1.681395e+09
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...  1.681395e+09
# 2                           /details.php?prod=5&type=%3F  1.681395e+09
# 3                        /details.php?prod=7831&type=%3F  1.681395e+09
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...  1.681395e+09
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  1.681396e+09
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  1.681396e+09
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  1.681396e+09
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  1.681396e+09
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  1.681396e+09
#
#            hostname  injection  \
# 0      192.168.43.6          1
# 1      192.168.43.6          1
# 2      192.168.43.6          1
# 3      192.168.43.6          1
# 4      192.168.43.6          1
# ...             ...        ...
# 21398  192.168.43.6          0
# 21399  192.168.43.6          0
# 21400  192.168.43.6          0
# 21401  192.168.43.6          0
# 21402  192.168.43.6          0
#
#                                               parsed_url  sql_keyword  \
# 0                             /details.php?prod=5&type=?            0
# 1      /details.php?prod=5&type=?&GIuz=7549 AND 1=1 U...            8
# 2                             /details.php?prod=5&type=?            0
# 3                          /details.php?prod=7831&type=?            0
# 4                   /details.php?prod=5"',.(((,,,&type=?            0
# ...                                                  ...          ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...            1
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...            0
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...            0
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...            0
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...            0
#
#        params_length request_volume  special_chars
# 0                  2            4.2              0
# 1                178            4.2              7
# 2                  2            4.2              0
# 3                  5            4.2              0
# 4                 13            4.2              2
# ...              ...            ...            ...
# 21398             48            0.5              0
# 21399             34            0.5              0
# 21400             37            0.5              0
# 21401             32            0.5              0
# 21402             28            0.5              0
#
# [21403 rows x 9 columns]

# %%
sql_records_df["values_to_length"] = (sql_records_df["sql_keyword"] + sql_records_df["special_chars"]) * 100 / sql_records_df["params_length"]

# %%
sql_records_df = sql_records_df.reindex(columns=['full_url', 'parsed_url', 'hostname', 'event_time',
                                                'sql_keyword', 'params_length', 'request_volume', 
                                                'special_chars', 'values_to_length', 'injection'])

# %%
sql_records_df
# Out:
#                                                 full_url  \
# 0                           /details.php?prod=5&type=%3F
# 1      /details.php?prod=5&type=%3F&GIuz=7549%20AND%2...
# 2                           /details.php?prod=5&type=%3F
# 3                        /details.php?prod=7831&type=%3F
# 4      /details.php?prod=5%22%27%2C.%28%28%28%2C%2C%2...
# ...                                                  ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...
#
#                                               parsed_url      hostname  \
# 0                             /details.php?prod=5&type=?  192.168.43.6
# 1      /details.php?prod=5&type=?&GIuz=7549 AND 1=1 U...  192.168.43.6
# 2                             /details.php?prod=5&type=?  192.168.43.6
# 3                          /details.php?prod=7831&type=?  192.168.43.6
# 4                   /details.php?prod=5"',.(((,,,&type=?  192.168.43.6
# ...                                                  ...           ...
# 21398  /details.php?type=NFGCVXOINZFWXTOGXHSPDAGOAKBB...  192.168.43.6
# 21399  /details.php?type=SKNSBV&prod=DIKRVZSYGNTAKAQJ...  192.168.43.6
# 21400  /details.php?type=RGWZVRWBQAZDG&prod=SYJEEIXZS...  192.168.43.6
# 21401  /details.php?type=EHFZ&prod=WTOTSYLRJLXXJKAYVU...  192.168.43.6
# 21402  /details.php?type=XLELQAICVH&prod=EOQHTJKTXRHV...  192.168.43.6
#
#          event_time  sql_keyword  params_length request_volume  special_chars  \
# 0      1.681395e+09            0              2            4.2              0
# 1      1.681395e+09            8            178            4.2              7
# 2      1.681395e+09            0              2            4.2              0
# 3      1.681395e+09            0              5            4.2              0
# 4      1.681395e+09            0             13            4.2              2
# ...             ...          ...            ...            ...            ...
# 21398  1.681396e+09            1             48            0.5              0
# 21399  1.681396e+09            0             34            0.5              0
# 21400  1.681396e+09            0             37            0.5              0
# 21401  1.681396e+09            0             32            0.5              0
# 21402  1.681396e+09            0             28            0.5              0
#
#        values_to_length  injection
# 0              0.000000          1
# 1              8.426966          1
# 2              0.000000          1
# 3              0.000000          1
# 4             15.384615          1
# ...                 ...        ...
# 21398          2.083333          0
# 21399          0.000000          0
# 21400          0.000000          0
# 21401          0.000000          0
# 21402          0.000000          0
#
# [21403 rows x 10 columns]

# %%
sql_records_df.to_csv("sql_df_preprocessed.csv", index=False)

# %% [markdown]
# ## Lista skanerów SQLinjection:
# - SQLMap – Automatic SQL injection and database
# - jSQL Injection – Java tool for automatic SQL
# - DSSS – Damn small SQLi scanner
